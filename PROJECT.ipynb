# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_dict= pd.read_excel(r"/content/Book1.xlsx", sheet_name=None)

# %%
df=df_dict

# %% [markdown]
# ## **Data collection and cleaning**

# %%
df.keys()
# Out:
# dict_keys(['EducationLevel', 'Employee', 'PerformanceRating', 'RatingLevel', 'SatisfiedLevel'])

# %%
Employee_1=df['Employee']

# %%
Employee_1.head()
# Out:
#   EmployeeID FirstName  LastName  Gender  Age BusinessTravel  Department  \
# 0  C08F-94F9     Nikos  Karpenko    Male   26    Some Travel  Technology
# 1  ADF8-AD57      Trip   Bennell    Male   27    Some Travel  Technology
# 2  6C42-A719      Bird    Libbey  Female   22    Some Travel  Technology
# 3  D014-7DB2     Dolli   Dodgson  Female   20    Some Travel       Sales
# 4  FD95-9EEB     Sasha   Incogna    Male   30    Some Travel  Technology
#
#    DistanceFromHome (KM) State Ethnicity  ...  MaritalStatus Salary  \
# 0                     32    NY     White  ...         Single  40100
# 1                     28    CA     White  ...         Single  20387
# 2                     37    NY     White  ...         Single  30442
# 3                     16    NY     White  ...         Single  35754
# 4                     19    IL     White  ...         Single  96187
#
#   StockOptionLevel OverTime   HireDate  Attrition YearsAtCompany  \
# ...

# %%
Employee_1.tail()
# Out:
#      EmployeeID FirstName     LastName      Gender  Age BusinessTravel  \
# 1465  B005-602F    Layney        Ratie      Female   19    Some Travel
# 1466  FF42-EA28   Madella       Worham      Female   18    Some Travel
# 1467  CB16-C876     April     Beckwith      Female   19    Some Travel
# 1468  8A34-59DF  Camellia  Shelmerdine  Non-Binary   19    Some Travel
# 1469  467E-977A       Jud    Melanaphy        Male   20    Some Travel
#
#       Department  DistanceFromHome (KM) State                  Ethnicity  ...  \
# 1465  Technology                     11    CA  Black or African American  ...
# 1466  Technology                     14    IL  Black or African American  ...
# 1467  Technology                      2    CA  Black or African American  ...
# 1468  Technology                      5    CA  Black or African American  ...
# 1469  Technology                     28    CA  Black or African American  ...
#
# ...

# %%
Employee_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               1470 non-null   object
#  1   FirstName                1470 non-null   object
#  2   LastName                 1470 non-null   object
#  3   Gender                   1470 non-null   object
#  4   Age                      1470 non-null   int64
#  5   BusinessTravel           1470 non-null   object
#  6   Department               1470 non-null   object
#  7   DistanceFromHome (KM)    1470 non-null   int64
#  8   State                    1470 non-null   object
#  9   Ethnicity                1470 non-null   object
#  10  Education                1470 non-null   int64
#  11  EducationField           1470 non-null   object
#  12  JobRole                  1470 non-null   object
#  13  MaritalStatus            1470 non-null   object
# ...

# %%
Employee_1.columns
# Out:
# Index(['EmployeeID', 'FirstName', 'LastName', 'Gender', 'Age',
#        'BusinessTravel', 'Department', 'DistanceFromHome (KM)', 'State',
#        'Ethnicity', 'Education', 'EducationField', 'JobRole', 'MaritalStatus',
#        'Salary', 'StockOptionLevel', 'OverTime', 'HireDate', 'Attrition',
#        'YearsAtCompany', 'YearsInMostRecentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
Employee_1.duplicated(subset=['EmployeeID', 'FirstName', 'LastName', 'Gender', 'Age',
       'BusinessTravel', 'Department', 'DistanceFromHome (KM)', 'State',
       'Ethnicity', 'Education', 'EducationField', 'JobRole', 'MaritalStatus',
       'Salary', 'StockOptionLevel', 'OverTime', 'HireDate', 'Attrition',
       'YearsAtCompany', 'YearsInMostRecentRole', 'YearsSinceLastPromotion',
       'YearsWithCurrManager'], keep='first').sum()
# Out:
# 0

# %%
Employee_1.isnull().sum()
# Out:
# EmployeeID                 0
# FirstName                  0
# LastName                   0
# Gender                     0
# Age                        0
# BusinessTravel             0
# Department                 0
# DistanceFromHome (KM)      0
# State                      0
# Ethnicity                  0
# Education                  0
# EducationField             0
# JobRole                    0
# MaritalStatus              0
# Salary                     0
# StockOptionLevel           0
# OverTime                   0
# HireDate                   0
# Attrition                  0
# YearsAtCompany             0
# YearsInMostRecentRole      0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# dtype: int64

# %%
Employee_1.describe()
# Out:
#                Age  DistanceFromHome (KM)    Education         Salary  \
# count  1470.000000            1470.000000  1470.000000    1470.000000
# mean     28.989796              22.502721     2.912925  112956.497959
# min      18.000000               1.000000     1.000000   20387.000000
# 25%      23.000000              12.000000     2.000000   43580.500000
# 50%      26.000000              22.000000     3.000000   71199.500000
# 75%      34.000000              33.000000     4.000000  142055.750000
# max      51.000000              45.000000     5.000000  547204.000000
# std       7.993055              12.811124     1.024165  103342.889222
#
#        StockOptionLevel                       HireDate  YearsAtCompany  \
# count       1470.000000                           1470     1470.000000
# mean           0.793878  2017-07-05 14:50:26.938775552        4.562585
# min            0.000000            2012-01-03 00:00:00        0.000000
# ...

# %%
RatingLevel_1=df ['RatingLevel']

# %%
RatingLevel_1.head()
# Out:
#    RatingID          RatingLevel
# 0         1         Unacceptable
# 1         2    Needs Improvement
# 2         3    Meets Expectation
# 3         4  Exceeds Expectation
# 4         5     Above and Beyond

# %%
RatingLevel_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   RatingID     5 non-null      int64
#  1   RatingLevel  5 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 208.0+ bytes

# %%
RatingLevel_1.columns
# Out:
# Index(['RatingID', 'RatingLevel'], dtype='object')

# %%
RatingLevel_1.duplicated(subset=['RatingID', 'RatingLevel'], keep='first').sum()
# Out:
# 0

# %%
RatingLevel_1.isnull().sum()
# Out:
# RatingID       0
# RatingLevel    0
# dtype: int64

# %%
RatingLevel_1.describe()
# Out:
#        RatingID
# count  5.000000
# mean   3.000000
# std    1.581139
# min    1.000000
# 25%    2.000000
# 50%    3.000000
# 75%    4.000000
# max    5.000000

# %%
PerformanceRating_1=df ['PerformanceRating']

# %%
PerformanceRating_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6709 entries, 0 to 6708
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   PerformanceID                    6709 non-null   object
#  1   EmployeeID                       6709 non-null   object
#  2   ReviewDate                       6709 non-null   datetime64[ns]
#  3   EnvironmentSatisfaction          6709 non-null   int64
#  4   JobSatisfaction                  6709 non-null   int64
#  5   RelationshipSatisfaction         6709 non-null   int64
#  6   TrainingOpportunitiesWithinYear  6709 non-null   int64
#  7   TrainingOpportunitiesTaken       6709 non-null   int64
#  8   WorkLifeBalance                  6709 non-null   int64
#  9   SelfRating                       6709 non-null   int64
#  10  ManagerRating                    6709 non-null   int64
# dtypes: datetime64[ns](1), int64(8), object(2)
# ...

# %%
PerformanceRating_1.columns
# Out:
# Index(['PerformanceID', 'EmployeeID', 'ReviewDate', 'EnvironmentSatisfaction',
#        'JobSatisfaction', 'RelationshipSatisfaction',
#        'TrainingOpportunitiesWithinYear', 'TrainingOpportunitiesTaken',
#        'WorkLifeBalance', 'SelfRating', 'ManagerRating'],
#       dtype='object')

# %%
PerformanceRating_1.duplicated(subset=['PerformanceID', 'EmployeeID', 'ReviewDate', 'EnvironmentSatisfaction',
       'JobSatisfaction', 'RelationshipSatisfaction',
       'TrainingOpportunitiesWithinYear', 'TrainingOpportunitiesTaken',
       'WorkLifeBalance', 'SelfRating', 'ManagerRating'],keep='first').sum()
# Out:
# 0

# %%
PerformanceRating_1.isnull().sum()
# Out:
# PerformanceID                      0
# EmployeeID                         0
# ReviewDate                         0
# EnvironmentSatisfaction            0
# JobSatisfaction                    0
# RelationshipSatisfaction           0
# TrainingOpportunitiesWithinYear    0
# TrainingOpportunitiesTaken         0
# WorkLifeBalance                    0
# SelfRating                         0
# ManagerRating                      0
# dtype: int64

# %%
PerformanceRating_1.describe()
# Out:
#                           ReviewDate  EnvironmentSatisfaction  \
# count                           6709              6709.000000
# mean   2019-04-14 05:12:04.936652288                 3.872559
# min              2013-01-02 00:00:00                 1.000000
# 25%              2017-05-21 00:00:00                 3.000000
# 50%              2019-09-15 00:00:00                 4.000000
# 75%              2021-06-01 00:00:00                 5.000000
# max              2022-12-31 00:00:00                 5.000000
# std                              NaN                 0.940701
#
#        JobSatisfaction  RelationshipSatisfaction  \
# count      6709.000000               6709.000000
# mean          3.430616                  3.427336
# min           1.000000                  1.000000
# 25%           2.000000                  2.000000
# 50%           3.000000                  3.000000
# 75%           4.000000                  4.000000
# max           5.000000                  5.000000
# ...

# %%
EducationLevel_1=df ['EducationLevel']

# %%
EducationLevel_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   EducationLevelID  5 non-null      int64
#  1   EducationLevel    5 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 208.0+ bytes

# %%
EducationLevel_1.isnull().sum()
# Out:
# EducationLevelID    0
# EducationLevel      0
# dtype: int64

# %%
EducationLevel_1.columns
# Out:
# Index(['EducationLevelID', 'EducationLevel'], dtype='object')

# %%
EducationLevel_1.duplicated(subset=['EducationLevelID', 'EducationLevel'],keep="first").sum()
# Out:
# 0

# %%
EducationLevel_1.describe()
# Out:
#        EducationLevelID
# count          5.000000
# mean           3.000000
# std            1.581139
# min            1.000000
# 25%            2.000000
# 50%            3.000000
# 75%            4.000000
# max            5.000000

# %%
SatisfiedLevel_1=df["SatisfiedLevel"]

# %%
SatisfiedLevel_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SatisfactionID     5 non-null      int64
#  1   SatisfactionLevel  5 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 208.0+ bytes

# %%
SatisfiedLevel_1.isnull().sum()
# Out:
# SatisfactionID       0
# SatisfactionLevel    0
# dtype: int64

# %%
SatisfiedLevel_1.columns
# Out:
# Index(['SatisfactionID', 'SatisfactionLevel'], dtype='object')

# %%
SatisfiedLevel_1.duplicated(subset=['SatisfactionID','SatisfactionLevel'],keep="first").sum()
# Out:
# 0

# %%
SatisfiedLevel_1.describe()
# Out:
#        SatisfactionID
# count        5.000000
# mean         3.000000
# std          1.581139
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          4.000000
# max          5.000000

# %% [markdown]
# # **Data Visualization**

# %% [markdown]
# **Employee performance for age**

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=SatisfiedLevel_1["SatisfactionLevel"], y=Employee_1['Age'], palette="viridis")
plt.title('Age of Employees')
plt.xlabel('SatisfactionLevel')
plt.ylabel('Age')
plt.show()
# Out:
# <ipython-input-82-9f391dabcdaf>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=SatisfiedLevel_1["SatisfactionLevel"], y=Employee_1['Age'], palette="viridis")

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=RatingLevel_1['RatingLevel'], y=Employee_1['Age'], palette="viridis")
plt.title('Age of Employees')
plt.xlabel('RatingLevel')
plt.ylabel('Age')
plt.show()
# Out:
# <ipython-input-81-954b2dd403d8>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=RatingLevel_1['RatingLevel'], y=Employee_1['Age'], palette="viridis")

# %% [markdown]
# **Gender by Employees**

# %%
Gender_by_Employees=Employee_1['Gender'].value_counts()
Gender_by_Employees
# Out:
# Gender
# Female               675
# Male                 651
# Non-Binary           124
# Prefer Not To Say     20
# Name: count, dtype: int64

# %% [markdown]
# **Gender by Employees**

# %%
plt.pie(Gender_by_Employees,labels=Gender_count.index,autopct='%.2f')
plt.title('Gender Distribution of Employees')
plt.show()

# %% [markdown]
# **avg_salary_by_gender**

# %%
avg_salary_by_gender = Employee_1.groupby('Gender')['Salary'].mean()
avg_salary_by_gender
# Out:
# Gender
# Female               113935.691852
# Male                 111773.809524
# Non-Binary           111395.508065
# Prefer Not To Say    128083.350000
# Name: Salary, dtype: float64

# %% [markdown]
# **avg_salary_by_Department**

# %%
avg_salary_by_Department =Employee_1.groupby('Department')['Salary'].mean()
avg_salary_by_Department
# Out:
# Department
# Human Resources    119698.809524
# Sales              119117.609865
# Technology         109655.122789
# Name: Salary, dtype: float64

# %% [markdown]
# **count Employees by Department**

# %%
Employee_1['Department'].value_counts()
# Out:
# Department
# Technology         961
# Sales              446
# Human Resources     63
# Name: count, dtype: int64

# %% [markdown]
# **Travel for Employees**

# %%
Travel=Employee_1['BusinessTravel'].value_counts()
Travel
# Out:
# BusinessTravel
# Some Travel           1043
# Frequent Traveller     277
# No Travel              150
# Name: count, dtype: int64

# %% [markdown]
# **Number of employees for the state**

# %%
Employee_count_for_state=Employee_1.groupby("State")["EmployeeID"].count()
Employee_count_for_state
# Out:
# State
# CA    875
# IL    176
# NY    419
# Name: EmployeeID, dtype: int64

# %% [markdown]
# **Max and Min for states**

# %%
Employee_1["State"].value_counts().head(1)
# Out:
# State
# CA    875
# Name: count, dtype: int64

# %%
Employee_1["State"].value_counts().tail(1)
# Out:
# State
# IL    176
# Name: count, dtype: int64

# %% [markdown]
# **Employee_jobsatisfaction**

# %%
Employee_jobsatisfaction=PerformanceRating_1.groupby("JobSatisfaction")["EmployeeID"].count()
Employee_jobsatisfaction
# Out:
# JobSatisfaction
# 1     130
# 2    1674
# 3    1651
# 4    1685
# 5    1569
# Name: EmployeeID, dtype: int64

# %% [markdown]
# **WorkLifeBalance_for_job**

# %%
WorkLifeBalance_for_job=PerformanceRating_1.groupby("WorkLifeBalance")["EmployeeID"].count()
WorkLifeBalance_for_job
# Out:
# WorkLifeBalance
# 1     121
# 2    1702
# 3    1670
# 4    1706
# 5    1510
# Name: EmployeeID, dtype: int64

# %% [markdown]
# **Ethnicity by Employees**

# %%
Ethnicity_by_employees =Employee_1["Ethnicity"].value_counts()
plt.figure(figsize=(10,6))
sns.barplot(y=Ethnicity_by_employees.index, x=Ethnicity_by_employees.values,color="green")
plt.title('Ethnicity by Employees')
plt.xlabel('Number of Employees')
plt.ylabel('Ethnicity')
plt.show()

# %% [markdown]
# **count Employees by JobRole**

# %%
Employee_1['JobRole'].value_counts()
# Out:
# JobRole
# Sales Executive              327
# Software Engineer            294
# Data Scientist               261
# Machine Learning Engineer    146
# Senior Software Engineer     132
# Sales Representative          83
# Engineering Manager           75
# Analytics Manager             52
# Manager                       37
# HR Executive                  28
# Recruiter                     24
# HR Business Partner            7
# HR Manager                     4
# Name: count, dtype: int64

# %% [markdown]
# **jobs_for_Avg_Salary**

# %%
top_jobs_for_Avg_Salary=Employee_1.groupby('JobRole')['Salary'].mean().sort_values(ascending=False).head(4)
top_jobs_for_Avg_Salary
# Out:
# JobRole
# HR Manager             449330.750000
# Analytics Manager      346484.230769
# Manager                317531.054054
# HR Business Partner    314002.428571
# Name: Salary, dtype: float64

# %% [markdown]
# **Number_of_YearsInMostRecentRole by travel**

# %%
Number_of_YearsInMostRecentRole=Employee_1.groupby("BusinessTravel")['YearsInMostRecentRole'].count()
Number_of_YearsInMostRecentRole
# Out:
# BusinessTravel
# Frequent Traveller     277
# No Travel              150
# Some Travel           1043
# Name: YearsInMostRecentRole, dtype: int64

# %% [markdown]
# **JobRole vs EducationField**

# %%
job=Employee_1.groupby("JobRole")["EducationField"].describe()
job
# Out:
#                           count unique                  top freq
# JobRole
# Analytics Manager            52      4  Information Systems   25
# Data Scientist              261      4     Computer Science  121
# Engineering Manager          75      4     Computer Science   34
# HR Business Partner           7      3            Marketing    3
# HR Executive                 28      4      Human Resources   13
# HR Manager                    4      1      Human Resources    4
# Machine Learning Engineer   146      4     Computer Science   71
# Manager                      37      3            Marketing   30
# Recruiter                    24      4      Human Resources    8
# Sales Executive             327      4            Marketing  229
# Sales Representative         83      4            Marketing   50
# Senior Software Engineer    132      4     Computer Science   61
# Software Engineer           294      4     Computer Science  133

# %% [markdown]
# **Gender_by_Department**

# %%
Gender_by_Department = Employee_1.groupby('Gender')['Department'].value_counts()
Gender_by_Department
# Out:
# Gender             Department
# Female             Technology         438
#                    Sales              204
#                    Human Resources     33
# Male               Technology         423
#                    Sales              204
#                    Human Resources     24
# Non-Binary         Technology          84
#                    Sales               35
#                    Human Resources      5
# Prefer Not To Say  Technology          16
#                    Sales                3
#                    Human Resources      1
# Name: count, dtype: int64

# %% [markdown]
# **count Employees by EducationField**

# %%
plt.figure(figsize=(10,6))
count_Employees_by_EducationField.plot(kind='bar', color='lightblue')
plt.title('count Employees by EducationField')
plt.ylabel('count Employees')
plt.xlabel('EducationField')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **EducationField_by_Department**

# %%
EducationField_by_Department=Employee_1.groupby("EducationField")["Department"].value_counts()
EducationField_by_Department
# Out:
# EducationField       Department
# Business Studies     Technology          94
# Computer Science     Technology         440
# Economics            Sales               88
#                      Human Resources     13
# Human Resources      Human Resources     27
# Information Systems  Technology         363
# Marketing            Sales              309
#                      Human Resources     16
# Other                Technology          64
#                      Sales               15
#                      Human Resources      3
# Technical Degree     Sales               34
#                      Human Resources      4
# Name: count, dtype: int64

# %% [markdown]
# **count_Employees_by_EducationField**

# %%
count_Employees_by_EducationField=Employee_1.groupby("EducationField")["EmployeeID"].count()
count_Employees_by_EducationField
# Out:
# EducationField
# Business Studies        94
# Computer Science       440
# Economics              101
# Human Resources         27
# Information Systems    363
# Marketing              325
# Other                   82
# Technical Degree        38
# Name: EmployeeID, dtype: int64
